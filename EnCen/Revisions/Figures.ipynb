# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
binary = pd.read_csv('/home/anna/Documents/EcoGenoRisk_Paper_Revisions/Functional profile/all_biopesticide_functional_profile.txt', delimiter = ' ', index_col= 0) #this is every genome, EC, and the biome it is in. Cresten Concatanated each dataframe. 
binary
# Out:
#                                         1.1.1.1  1.1.1.2  1.1.1.3  1.1.1.4  \
# Name_of_MetaGenome_Bin
# Methylorubrum_extorquens_matches.tsv          1        0        1        0
# Bacillus_paralicheniformis_matches.tsv        1        0        1        0
# Wolbachia_pipientis_matches.tsv               0        0        0        0
# Kosakonia_cowanii_matches.tsv                 1        1        0        0
# Gluconobacter_cerinus_matches.tsv             1        1        1        0
# Bacillus_amyloliquefaciens_matches.tsv        1        0        1        1
# Bacillus_Subtilis_matches.tsv                 0        0        1        1
# Bacillus_velezensis_matches.tsv               1        0        1        1
# Matheylorubrum_populi_matches.tsv             0        0        1        0
# Baccilus_Licheniformis_matches.tsv            0        0        1        0
#
#                                         1.1.1.5  1.1.1.6  1.1.1.7  1.1.1.8  \
# Name_of_MetaGenome_Bin
# ...
