# %%
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy.stats import norm, gamma, lognorm, weibull_min, gaussian_kde, skew, genpareto
from matplotlib.ticker import FuncFormatter
import os

# %%
as_all = pd.read_excel('Biome Synbio Top Match EC Comparison.xlsx')
as_all53 = as_all[as_all['Percentage'] > 0]
as_lost53 = pd.read_excel('/home/anna/Desktop/JD_Niche_OverLap (Git)/Niche_JD/Eco_V2/EnCen/Figures for paper/Lost_Functions.xlsx')
as_present53 = pd.read_excel('Only Present Enzyme Biome Synbio Top Match EC Comparison.xlsx')
added_EC53 = as_all53[(as_all53['Synbio Presence/Absence'] == 1) & (as_all53['Top Match Presence/Absence'] == 0)]
as_overlap53 = as_all53[(as_all53['Synbio Presence/Absence'] == 1) & (as_all53['Top Match Presence/Absence'] == 1)]
as_lost53
# Out:
#     EC Number  Percentage                                               Name  \
# 0     7.5.2.6   90.240350  ABC-type lipid A-core oligosaccharide transpor...
# 1     2.1.2.9   85.797524                  methionyl-tRNA formyltransferase.
# 2    6.1.1.16   85.214858                             cysteine--tRNA ligase.
# 3    2.8.1.13   84.777859                  tRNA-uridine 2-sulfurtransferase.
# 4     6.1.1.9   84.195193                               valine--tRNA ligase.
# 5    2.5.1.75   83.466861                     tRNA dimethylallyltransferase.
# 6     2.8.4.3   76.183540  tRNA-2-methylthio-N(6)-dimethylallyladenosine ...
# 7     2.7.6.5   73.707210                               GTP diphosphokinase.
# 8    3.1.13.1   71.449381                                exoribonuclease II.
# 9     1.5.1.3   61.325564                           dihydrofolate reductase.
# 10    7.6.2.5   37.072105                         ABC-type heme transporter.
# 11  3.4.24.70   32.119446                                  oligopeptidase A.
# 12   3.1.21.4   31.463948           type II site-specific deoxyribonuclease.
# 13    1.4.1.2   25.637291                           glutamate dehydrogenase.
# 14   3.1.21.5   14.712309          type III site-specific deoxyribonuclease.
#
#     Synbio Presence/Absence  Top Match Presence/Absence
# 0                         0                           1
# 1                         0                           1
# 2                         0                           1
# 3                         0                           1
# 4                         0                           1
# 5                         0                           1
# 6                         0                           1
# 7                         0                           1
# 8                         0                           1
# 9                         0                           1
# 10                        0                           1
# 11                        0                           1
# 12                        0                           1
# 13                        0                           1
# 14                        0                           1

# %%
bin_edges = range(0, 101, 5)
sns.histplot(x='Percentage', bins = bin_edges, data = added_EC53, color='black', label = 'Present Functions', kde = True, alpha = 0.5)
sns.histplot(x='Percentage',bins=bin_edges, data = as_overlap53, color = 'red', label='Added Functions', kde= True, alpha = 0.5)
plt.show()

# %%
sns.set_style('white')
ax = df.plot(kind='bar', stacked=True, color = sns.color_palette("husl", 3))
ax.tick_params(axis='x', rotation=45)
# plt.xticks(range(0, 100), 10)  # every 2nd label
plt.xticks(rotation = 45, ha = 'right')
plt.xlabel('Bin Percentage')
plt.ylabel('EC Count')
# Out:
# Text(0, 0.5, 'EC Count')

# %%
bin_edges = range(0, 101, 5)
sns.histplot(x='Percentage', bins = bin_edges, data = as_lost53, color='blue', label = 'Displaced Functions', alpha = 0.8)
sns.histplot(x='Percentage',bins=bin_edges, data = added_EC53, color = 'red', label='Added Functions', alpha = 0.5)
plt.xlabel('Bin Percentage')
plt.ylabel('EC Count')
plt.title('Bin Completeness = 53.45%')
plt.legend()
plt.savefig('/home/anna/Desktop/A&L_53%.svg', format='svg')
plt.show()

# %%
bin_edges = range(0, 101, 5)

plt.hist([as_lost53['Percentage'], as_overlap53['Percentage'],added_EC53['Percentage']], 
         bins=bin_edges, 
         label=['Displaced Functions', 'Overlap Functions','Added Functions'],
         color=['blue', 'purple', 'red'],
         alpha=0.5,
         stacked=True)

plt.xlabel('Bin Percentage')
plt.ylabel('EC Count')
plt.title('Bin Completeness = 53.45%')
plt.ylim(0, 80)
plt.yticks(range(0, 81, 10))
plt.legend()
plt.savefig('/home/anna/Desktop/A&L_53%.svg', format='svg')

# %%
as_overlap53
# Out:
#      EC Number  Percentage                                               Name  \
# 0      2.7.7.7  100.000000                       DNA-directed DNA polymerase.
# 1     3.6.4.12   99.781500                                      DNA helicase.
# 2      5.2.1.8   99.781500                          peptidylprolyl isomerase.
# 3     2.7.13.3   98.980335                                  histidine kinase.
# 4      5.6.2.4   98.397669                                DNA 3'-5' helicase.
# ..         ...         ...                                                ...
# 405    2.1.3.3   45.156591                    ornithine carbamoyltransferase.
# 471    2.8.4.5   38.601602  tRNA (N(6)-L-threonylcarbamoyladenosine(37)-C(...
# 499  2.1.1.166   36.416606   23S rRNA (uridine(2552)-2'-O)-methyltransferase.
# 583    3.6.4.6   30.444283                             vesicle-fusing ATPase.
# 642    2.7.7.2   26.656956                                      FAD synthase.
#
#      Synbio Presence/Absence  Top Match Presence/Absence
# 0                          1                           1
# 1                          1                           1
# 2                          1                           1
# 3                          1                           1
# 4                          1                           1
# ..                       ...                         ...
# 405                        1                           1
# 471                        1                           1
# 499                        1                           1
# 583                        1                           1
# 642                        1                           1
#
# [78 rows x 5 columns]

# %%
added_EC53
# Out:
#       EC Number  Percentage  \
# 13     2.7.7.65   93.008012
# 38     2.7.7.87   85.797524
# 72      3.6.5.4   82.665696
# 80     3.6.1.27   82.010197
# 84      1.8.1.8   81.791697
# ...         ...         ...
# 3459  2.7.1.237    0.072833
# 3476   2.1.1.86    0.072833
# 3588   1.2.1.90    0.072833
# 3598  2.1.1.216    0.072833
# 3611   6.3.2.36    0.072833
#
#                                                    Name  \
# 13                                 diguanylate cyclase.
# 38               L-threonylcarbamoyladenylate synthase.
# 72                  signal-recognition-particle GTPase.
# 80                undecaprenyl-diphosphate phosphatase.
# 84                         protein-disulfide reductase.
# ...                                                 ...
# 3459                GTP-dependent dephospho-CoA kinase.
# 3476                        Transferred entry: 7.2.1.4.
# 3588  glyceraldehyde-3-phosphate dehydrogenase [NAD(...
# 3598       tRNA (guanine(26)-N(2))-dimethyltransferase.
# 3611            4-phosphopantoate--beta-alanine ligase.
#
#       Synbio Presence/Absence  Top Match Presence/Absence
# 13                          1                           0
# 38                          1                           0
# 72                          1                           0
# 80                          1                           0
# 84                          1                           0
# ...                       ...                         ...
# 3459                        1                           0
# 3476                        1                           0
# 3588                        1                           0
# 3598                        1                           0
# 3611                        1                           0
#
# [309 rows x 5 columns]

# %%
as_lost53
# Out:
#     EC Number  Percentage                                               Name  \
# 0     7.5.2.6   90.240350  ABC-type lipid A-core oligosaccharide transpor...
# 1     2.1.2.9   85.797524                  methionyl-tRNA formyltransferase.
# 2    6.1.1.16   85.214858                             cysteine--tRNA ligase.
# 3    2.8.1.13   84.777859                  tRNA-uridine 2-sulfurtransferase.
# 4     6.1.1.9   84.195193                               valine--tRNA ligase.
# 5    2.5.1.75   83.466861                     tRNA dimethylallyltransferase.
# 6     2.8.4.3   76.183540  tRNA-2-methylthio-N(6)-dimethylallyladenosine ...
# 7     2.7.6.5   73.707210                               GTP diphosphokinase.
# 8    3.1.13.1   71.449381                                exoribonuclease II.
# 9     1.5.1.3   61.325564                           dihydrofolate reductase.
# 10    7.6.2.5   37.072105                         ABC-type heme transporter.
# 11  3.4.24.70   32.119446                                  oligopeptidase A.
# 12   3.1.21.4   31.463948           type II site-specific deoxyribonuclease.
# 13    1.4.1.2   25.637291                           glutamate dehydrogenase.
# 14   3.1.21.5   14.712309          type III site-specific deoxyribonuclease.
#
#     Synbio Presence/Absence  Top Match Presence/Absence
# 0                         0                           1
# 1                         0                           1
# 2                         0                           1
# 3                         0                           1
# 4                         0                           1
# 5                         0                           1
# 6                         0                           1
# 7                         0                           1
# 8                         0                           1
# 9                         0                           1
# 10                        0                           1
# 11                        0                           1
# 12                        0                           1
# 13                        0                           1
# 14                        0                           1

# %%
os.chdir('/home/anna/Desktop/Eco_geno_C_figures/higher_completion_bins/61')
as_all61 = pd.read_excel('Biome Synbio Top Match EC Comparison.xlsx')
as_all61 = as_all61[as_all61['Percentage'] > 0]
as_lost61 = pd.read_excel('Lost_Functions.xlsx')
as_present61 = pd.read_excel('Only Present Enzyme Biome Synbio Top Match EC Comparison.xlsx')
added_EC61 = as_all61[(as_all61['Synbio Presence/Absence'] == 1) & (as_all61['Top Match Presence/Absence'] == 0)]
as_overlap61 = as_all61[(as_all61['Synbio Presence/Absence'] == 1) & (as_all61['Top Match Presence/Absence'] == 1)]

# %%
bin_edges = range(0, 101, 5)

plt.hist([as_lost61['Percentage'], as_overlap61['Percentage'], added_EC61['Percentage']], 
         bins=bin_edges, 
         label=['Displaced Functions', 'Overlap Functions', 'Added Functions'],
         color=['blue', 'purple', 'red'],
         alpha=0.5,
         stacked=True)

plt.xlabel('Bin Percentage')
plt.ylabel('EC Count')
plt.title('61.37%')
plt.ylim(0, 80)
plt.yticks(range(0, 81, 10))
plt.legend()
plt.savefig('/home/anna/Desktop/A&L_61%.svg', format='svg')

# %%
os.chdir('/home/anna/Desktop/Eco_geno_C_figures/higher_completion_bins/84')
as_all84 = pd.read_excel('Biome Synbio Top Match EC Comparison.xlsx')
as_all84 = as_all84[as_all84['Percentage'] > 0]
as_lost84 = pd.read_excel('Lost_Functions.xlsx')
as_present84 = pd.read_excel('Only Present Enzyme Biome Synbio Top Match EC Comparison.xlsx')
added_EC84 = as_all84[(as_all84['Synbio Presence/Absence'] == 1) & (as_all84['Top Match Presence/Absence'] == 0)]
as_overlap84 = as_all84[(as_all84['Synbio Presence/Absence'] == 1) & (as_all84['Top Match Presence/Absence'] == 1)]

# %%
bin_edges = range(0, 101, 5)

plt.hist([as_lost84['Percentage'], as_overlap84['Percentage'], added_EC84['Percentage']], 
         bins=bin_edges, 
         label=['Displaced Functions', 'Overlap Functions', 'Added Functions'],
         color=['blue', 'purple', 'red'],
         alpha=0.5,
         stacked=True)

plt.xlabel('Bin Percentage')
plt.ylabel('EC Count')
plt.title('84.27%')
plt.ylim(0, 80)
plt.yticks(range(0, 81, 10))
plt.legend()
plt.savefig('/home/anna/Desktop/A&L_84%.svg', format='svg')
